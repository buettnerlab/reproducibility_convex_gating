# %%
import convexgating as cg
import scanpy as sc
import anndata as ann
import numpy as np
import pandas as pd
#sc.logging.print_header()
file_path = '/work/users/mh823zote/projects/gating/data/CITEseq_Covid/' 
data_dir = file_path + 'data/'

# %%
adata = sc.read_h5ad(data_dir + 'pdata_CD16_CD4_sub_raw.h5ad')

# %%
sc.pp.log1p(adata)

# %%
cluster_string = 'CD16+ T cells'

# %% [markdown]
# ## Minimal panel

# %%
minimal_panel = ['AB_CD3','AB_CD4','AB_CD8','AB_CD16']
adata = adata[:,minimal_panel]
adata = adata.copy()

# %%
cg.tools.gating_strategy
# Out:
# <function convexgating.tools.gating_strategy(adata, cluster_numbers, cluster_string, save_path='/work/users/mh823zote/projects/gating/data/CITEseq_Covid/run_gating_raw_minimal_panel', add_noise=False)>

# %%
adata = adata.copy()
cluster_numbers = ['CD16+ CD4+ T cell']
cg.tools.gating_strategy(adata,cluster_numbers,cluster_string = cluster_string, add_noise=True)
# Out:
#            hierarchy_1  hierarchy_2  hierarchy_3  hierarchy_4  hierarchy_5
# f1            0.299860     0.448712     0.470292     0.499703     0.500301
# recall        0.663223     0.530992     0.482438     0.433884     0.428719
# precision     0.193724     0.388511     0.458743     0.589060     0.600579
