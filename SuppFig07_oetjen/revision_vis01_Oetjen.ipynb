# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats, interpolate
import pandas as pd
from scipy.interpolate import RegularGridInterpolator
from scipy.ndimage import gaussian_filter
import os

import contour_scatter as csc
import helper_strategy_visualization as hsv
import os

# %%
notebook_ID = 'revision_vis01_Oetjen'

# %% [markdown]
# **level 2**

# %%
add_hull_path = os.path.join(os.getcwd(),notebook_ID)
if not os.path.exists(add_hull_path):
    os.mkdir(add_hull_path)
add_hull_path = os.path.join(os.getcwd(),notebook_ID,'lvl2_sample_A')
if not os.path.exists(add_hull_path):
    os.mkdir(add_hull_path)

# %%
# %%capture
meta_info_path = os.path.join('C:\\Users\\vfriedrich\\projects','gating','reproducibility_cleaned','supp_Figure_oetjen','P01_cell_type_lvl2','A','meta_info.npy')
meta_info = np.load(meta_info_path,allow_pickle=True).item()
population,population_path,base_df = hsv.prepare_contour_plot(meta_info = meta_info,
                                                          add_hull_path =add_hull_path,
                                                          run_ID =0)

# %%
population
# Out:
# 'T cell'

# %%
run_ID = 0
save_pdf = os.path.join(add_hull_path, str(population) + '_gating_strategy.pdf')
save_png = os.path.join(add_hull_path, str(population) + '_gating_strategy.png')
forward, inverse = csc.arcsinh_transform(divisor=5.0)

# %%
csc.contour_lines_separate_outliers(meta_info, run_ID, base_df, population,population_path,
                    num_hierarchies=2, 
                    mode='both', # None or 'replace'  
                    transform_func=forward, 
                    inverse_transform_func=inverse, # you can use arcsinh/sinh here, too. Please check docs
                    save = save_pdf,
                            save_png=save_png,
                                linear_threshold=9.99)
# Out:
# nr_targets :31123
# nr_non_targets :18877
# nr_targets :30182
# nr_non_targets :253

# %% [markdown]
# **level 5**

# %%
add_hull_path = os.path.join(os.getcwd(),notebook_ID)
if not os.path.exists(add_hull_path):
    os.mkdir(add_hull_path)
add_hull_path = os.path.join(os.getcwd(),notebook_ID,'lvl5_sample_A')
if not os.path.exists(add_hull_path):
    os.mkdir(add_hull_path)

# %%
# %%capture
meta_info_path = os.path.join('C:\\Users\\vfriedrich\\projects','gating','reproducibility_cleaned','supp_Figure_oetjen','P01_cell_type_lvl5','A','meta_info.npy')
meta_info = np.load(meta_info_path,allow_pickle=True).item()
population,population_path,base_df = hsv.prepare_contour_plot(meta_info = meta_info,
                                                          add_hull_path =add_hull_path,
                                                          run_ID =4)

# %%
population
# Out:
# 'CD4+ TEMRA'

# %%
run_ID = 4
save_pdf = os.path.join(add_hull_path, str(population) + '_gating_strategy.pdf')
save_png = os.path.join(add_hull_path, str(population) + '_gating_strategy.png')
forward, inverse = csc.arcsinh_transform(divisor=5.0)

# %%
csc.contour_lines_separate_outliers(meta_info, run_ID, base_df, population,population_path,
                    num_hierarchies=5, 
                    mode='both', # None or 'replace'  
                    transform_func=forward, 
                    inverse_transform_func=inverse, # you can use arcsinh/sinh here, too. Please check docs
                    save = save_pdf,
                            save_png=save_png,
                                linear_threshold=9.99)
# Out:
# nr_targets :3800
# nr_non_targets :46200
# nr_targets :3410
# nr_non_targets :572
# nr_targets :3402
# nr_non_targets :522
# nr_targets :3344
# nr_non_targets :98
# nr_targets :3317
# nr_non_targets :37
