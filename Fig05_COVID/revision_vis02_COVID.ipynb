# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats, interpolate
import pandas as pd
from scipy.interpolate import RegularGridInterpolator
from scipy.ndimage import gaussian_filter
import os

import contour_scatter as csc
import helper_strategy_visualization as hsv
import os

# %%
notebook_ID = 'revision_vis02_COVID'

# %% [markdown]
# **C7**

# %%
add_hull_path = os.path.join(os.getcwd(),notebook_ID)
if not os.path.exists(add_hull_path):
    os.mkdir(add_hull_path)
add_hull_path = os.path.join(os.getcwd(),notebook_ID,'C7')
if not os.path.exists(add_hull_path):
    os.mkdir(add_hull_path)

# %%
# %%capture
meta_info_path = os.path.join('C:\\Users\\vfriedrich\\projects','gating','reproducibility_cleaned','main_Figure_COVID','output_data','COV02_run_gating','C7','meta_info.npy')
meta_info = np.load(meta_info_path,allow_pickle=True).item()
population,population_path,base_df = hsv.prepare_contour_plot(meta_info = meta_info,
                                                          add_hull_path = add_hull_path,
                                                          run_ID =0)

# %%
run_ID = 0
save_pdf = os.path.join(add_hull_path, str(population) + '_gating_strategy.pdf')
save_png = os.path.join(add_hull_path, str(population) + '_gating_strategy.png')
forward, inverse = csc.arcsinh_transform(divisor=5.0)

# %%
csc.contour_lines_separate_outliers(meta_info, run_ID, base_df, population,population_path,
                    num_hierarchies=4, 
                    mode='both', # None or 'replace'  
                    transform_func=forward, 
                    inverse_transform_func=inverse, # you can use arcsinh/sinh here, too. Please check docs
                    save = save_pdf,
                            save_png=save_png,
                                linear_threshold=9.99)
# Out:
# nr_targets :3125
# nr_non_targets :46875
# nr_targets :2248
# nr_non_targets :2160
# nr_targets :2079
# nr_non_targets :1018
# nr_targets :1936
# nr_non_targets :684

# %% [markdown]
# **C8**

# %%
add_hull_path = os.path.join(os.getcwd(),notebook_ID)
if not os.path.exists(add_hull_path):
    os.mkdir(add_hull_path)
add_hull_path = os.path.join(os.getcwd(),notebook_ID,'C8')
if not os.path.exists(add_hull_path):
    os.mkdir(add_hull_path)

# %%
# %%capture
meta_info_path = os.path.join('C:\\Users\\vfriedrich\\projects','gating','reproducibility_cleaned','main_Figure_COVID','output_data','COV02_run_gating','C8','meta_info.npy')
meta_info = np.load(meta_info_path,allow_pickle=True).item()
population,population_path,base_df = hsv.prepare_contour_plot(meta_info = meta_info,
                                                          add_hull_path =add_hull_path,
                                                          run_ID =0)

# %%
run_ID = 0
save_pdf = os.path.join(add_hull_path, str(population) + '_gating_strategy.pdf')
save_png = os.path.join(add_hull_path, str(population) + '_gating_strategy.png')
forward, inverse = csc.arcsinh_transform(divisor=5.0)

# %%
csc.contour_lines_separate_outliers(meta_info, run_ID, base_df, population,population_path,
                    num_hierarchies=2, 
                    mode='both', # None or 'replace'  
                    transform_func=forward, 
                    inverse_transform_func=inverse, # you can use arcsinh/sinh here, too. Please check docs
                    save = save_pdf,
                            save_png=save_png,
                                linear_threshold=9.99)
# Out:
# nr_targets :2287
# nr_non_targets :34305
# nr_targets :1743
# nr_non_targets :4125

# %% [markdown]
# **C25**

# %%
add_hull_path = os.path.join(os.getcwd(),notebook_ID)
if not os.path.exists(add_hull_path):
    os.mkdir(add_hull_path)
add_hull_path = os.path.join(os.getcwd(),notebook_ID,'C25')
if not os.path.exists(add_hull_path):
    os.mkdir(add_hull_path)

# %%
# %%capture
meta_info_path = os.path.join('C:\\Users\\vfriedrich\\projects','gating','reproducibility_cleaned','main_Figure_COVID','output_data','COV02_run_gating','C25','meta_info.npy')
meta_info = np.load(meta_info_path,allow_pickle=True).item()
population,population_path,base_df = hsv.prepare_contour_plot(meta_info = meta_info,
                                                          add_hull_path =add_hull_path,
                                                          run_ID =0)

# %%
run_ID = 0
save_pdf = os.path.join(add_hull_path, str(population) + '_gating_strategy.pdf')
save_png = os.path.join(add_hull_path, str(population) + '_gating_strategy.png')
forward, inverse = csc.arcsinh_transform(divisor=5.0)

# %%
csc.contour_lines_separate_outliers(meta_info, run_ID, base_df, population,population_path,
                    num_hierarchies=2, 
                    mode='both', # None or 'replace'  
                    transform_func=forward, 
                    inverse_transform_func=inverse, # you can use arcsinh/sinh here, too. Please check docs
                    save = save_pdf,
                            save_png=save_png,
                                linear_threshold=9.99)
# Out:
# nr_targets :3125
# nr_non_targets :46875
# nr_targets :2450
# nr_non_targets :1217

# %% [markdown]
# **C26**

# %%
add_hull_path = os.path.join(os.getcwd(),notebook_ID)
if not os.path.exists(add_hull_path):
    os.mkdir(add_hull_path)
add_hull_path = os.path.join(os.getcwd(),notebook_ID,'C26')
if not os.path.exists(add_hull_path):
    os.mkdir(add_hull_path)

# %%
# %%capture
meta_info_path = os.path.join('C:\\Users\\vfriedrich\\projects','gating','reproducibility_cleaned','main_Figure_COVID','output_data','COV02_run_gating','C26','meta_info.npy')
meta_info = np.load(meta_info_path,allow_pickle=True).item()
population,population_path,base_df = hsv.prepare_contour_plot(meta_info = meta_info,
                                                          add_hull_path =add_hull_path,
                                                          run_ID =0)

# %%
run_ID = 0
save_pdf = os.path.join(add_hull_path, str(population) + '_gating_strategy.pdf')
save_png = os.path.join(add_hull_path, str(population) + '_gating_strategy.png')
forward, inverse = csc.arcsinh_transform(divisor=5.0)

# %%
csc.contour_lines_separate_outliers(meta_info, run_ID, base_df, population,population_path,
                    num_hierarchies=3, 
                    mode='both', # None or 'replace'  
                    transform_func=forward, 
                    inverse_transform_func=inverse, # you can use arcsinh/sinh here, too. Please check docs
                    save = save_pdf,
                            save_png=save_png,
                                linear_threshold=9.99)
# Out:
# nr_targets :892
# nr_non_targets :13380
# nr_targets :669
# nr_non_targets :596
# nr_targets :650
# nr_non_targets :128
