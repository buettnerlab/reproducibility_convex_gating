# %%
import sys
import os
path_helper = ["c:\\","Users","vfriedrich","projects","gating","reproducibility_cleaned","helper"]
sys.path.append(os.path.join(*path_helper))
import helper_reproducibility as hr
import convexgating as cg
import scanpy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import colors
import seaborn as sb
import os
print(sys.executable)
# Out:
# C:\Users\vfriedrich\Anaconda3\envs\gating_env_local_parameter_option\python.exe

# %%
pre = 'COV03_summary_scores'
start_time = hr.get_time()

# %%
path_input_data = hr.return_input_data_path() 
path_output_data = hr.return_output_data_path()
path_output_script = os.path.join(path_output_data,pre)
hr.make_path(os.path.join(path_output_script))
# Out:
# path exists

# %% [markdown]
# ## Summarize best scores

# %%
path_gating_directory = os.path.join(path_output_data,'COV02_run_gating')

# %%
clusters = ['C7','C8','C25','C26']

# %%
cluster_list = []
f1_list = []
recall_list = []
precision_list = []
hierarchy_list = []
for cluster in clusters:
    perf_loc = os.path.join(path_gating_directory, cluster,'cluster_' + cluster,'performance.csv')
    f1,recall,precision,hierarchy = hr.get_f1_hierarch(perf_loc)
    cluster_list.append(cluster)
    f1_list.append(f1)
    recall_list.append(recall)
    precision_list.append(precision)
    hierarchy_list.append(hierarchy)

# %%
df_summary =pd.DataFrame({'f1':f1_list,'recall':recall_list,'precision':precision_list, 'cluster' : cluster_list})
df_summary.to_csv(os.path.join(path_output_script,pre + '_df.csv'))

# %%
df_summary
# Out:
#          f1    recall  precision cluster
# 0  0.676877  0.579840   0.812921      C7
# 1  0.551310  0.441627   0.733479      C8
# 2  0.744186  0.696320   0.799119     C25
# 3  0.792500  0.710762   0.895480     C26

# %% [markdown]
# ## Plot

# %%
df_summary_melted = pd.melt(df_summary[['f1','recall','precision','cluster']], id_vars="cluster", var_name="metric", value_name="score")

palette={"recall": "#e2998a","f1": "#663171","precision":"#0c7156"}
order=['C7','C8','C25','C26']

plt.figure()
sb.catplot(x='cluster', y="score", hue="metric", data=df_summary_melted,s=60, kind='swarm',palette=palette,order = order,height = 4,alpha = 0.8)
plt.ylim([0,1.03])
plt.savefig(os.path.join(path_output_script,pre + '_catplot_metrics.pdf'),bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# ## Save session

# %%
hr.save_package_versions(hr.return_base_package_version_path(),pre = pre,do_print = True)
sc.logging.print_versions()
end_time = hr.get_time()
hr.get_time_delta(start_time,end_time,pre=pre,save=True)
# Out:
# babel==2.13.1
# qtpy==2.4.1
# sqlalchemy==2.0.23
# send2trash==1.8.2
# anyio==4.1.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==2.4.1
# async-lru==2.0.4
# attrs==23.1.0
# beautifulsoup4==4.12.2
# bleach==6.1.0
# certifi==2023.11.17
# cffi==1.16.0
# charset-normalizer==3.3.2
# colorama==0.4.6
# comm==0.2.0
# debugpy==1.8.0
# decorator==5.1.1
# defusedxml==0.7.1
# exceptiongroup==1.2.0
# executing==2.0.1
# fastjsonschema==2.19.0
# fqdn==1.5.1
# greenlet==3.0.1
# idna==3.6
# importlib-metadata==7.0.0
# ipykernel==6.27.1
# ipython==8.18.1
# ipython-genutils==0.2.0
# ipython-sql==0.5.0
# ipywidgets==8.1.1
# isoduration==20.11.0
# jedi==0.19.1
# json5==0.9.14
# jsonpointer==2.4
# jsonschema==4.20.0
# jsonschema-specifications==2023.11.2
# jupyter==1.0.0
# jupyter-client==8.6.0
# jupyter-console==6.6.3
# jupyter-core==5.5.0
# jupyter-events==0.9.0
# jupyter-lsp==2.2.1
# jupyter-server==2.11.2
# jupyter-server-terminals==0.4.4
# jupyterlab==4.0.9
# jupyterlab-pygments==0.3.0
# jupyterlab-server==2.25.2
# jupyterlab-widgets==3.0.9
# matplotlib-inline==0.1.6
# mistune==3.0.2
# nbclient==0.9.0
# nbconvert==7.12.0
# nbformat==5.9.2
# nest-asyncio==1.5.8
# notebook==7.0.6
# notebook-shim==0.2.3
# overrides==7.4.0
# pandocfilters==1.5.0
# parso==0.8.3
# platformdirs==4.1.0
# prettytable==3.9.0
# prometheus-client==0.19.0
# prompt-toolkit==3.0.41
# pure-eval==0.2.2
# pycparser==2.21
# pygments==2.17.2
# python-json-logger==2.0.7
# pywin32==306
# pywinpty==2.0.12
# pyzmq==25.1.2
# qtconsole==5.5.1
# referencing==0.31.1
# requests==2.31.0
# rfc3339-validator==0.1.4
# rfc3986-validator==0.1.1
# rpds-py==0.13.2
# sniffio==1.3.0
# soupsieve==2.5
# sqlparse==0.4.4
# stack-data==0.6.3
# terminado==0.18.0
# tinycss2==1.2.1
# tomli==2.0.1
# traitlets==5.14.0
# types-python-dateutil==2.8.19.14
# uri-template==1.3.0
# urllib3==2.1.0
# wcwidth==0.2.12
# webcolors==1.13
# webencodings==0.5.1
# websocket-client==1.7.0
# widgetsnbextension==4.0.9
# brotli==1.0.9
# jinja2==3.1.3
# markupsafe==2.1.3
# pyqt5==5.15.10
# pyqt5-sip==12.13.0
# pysocks==1.7.1
# pyyaml==6.0.1
# anndata==0.10.5.post1
# array-api-compat==1.6
# backcall==0.2.0
# click==8.1.7
# contourpy==1.1.1
# convexgating==0.1.1
# cycler==0.12.1
# fonttools==4.51.0
# get-annotations==0.1.2
# h5py==3.11.0
# igraph==0.11.4
# joblib==1.4.0
# kiwisolver==1.4.5
# llvmlite==0.39.1
# markdown-it-py==3.0.0
# matplotlib==3.6.3
# mdurl==0.1.2
# natsort==8.4.0
# networkx==3.2.1
# numba==0.56.4
# numpy==1.19.5
# packaging==23.2
# pandas==1.4.4
# patsy==0.5.6
# pickleshare==0.7.5
# pillow==10.3.0
# pip==23.3.1
# ply==3.11
# psutil==5.9.0
# pydot==2.0.0
# pynndescent==0.5.12
# pyparsing==3.1.2
# python-dateutil==2.8.2
# python-igraph==0.11.4
# pytz==2023.3.post1
# pywget==0.31
# rich==13.7.1
# scanpy==1.9.6
# scikit-learn==1.4.2
# scikit-misc==0.1.4
# scipy==1.10.1
# seaborn==0.12.2
# session-info==1.0.0
# setuptools==68.2.2
# sip==6.7.12
# six==1.16.0
# statsmodels==0.14.1
# stdlib-list==0.10.0
# texttable==1.7.0
# threadpoolctl==3.4.0
# tk==0.1.0
# torch==1.7.1
# tornado==6.3.3
# tqdm==4.66.2
# typing-extensions==4.11.0
# umap-learn==0.5.6
# wheel==0.41.2
# win-inet-pton==1.1.0
# zipp==3.17.0
# -----
# anndata     0.10.5.post1
# scanpy      1.9.6
# -----
# PIL                         10.3.0
# anyio                       NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.1.0
# attrs                       23.1.0
# babel                       2.13.1
# brotli                      1.0.9
# certifi                     2023.11.17
# cffi                        1.16.0
# charset_normalizer          3.3.2
# colorama                    0.4.6
# comm                        0.2.0
# convexgating                NA
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.8.0
# decorator                   5.1.1
# defusedxml                  0.7.1
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fontTools                   4.51.0
# fqdn                        NA
# get_annotations             NA
# h5py                        3.11.0
# helper_reproducibility      NA
# idna                        3.6
# ipykernel                   6.27.1
# ipywidgets                  8.1.1
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.4.0
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.20.0
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.11.2
# jupyterlab_server           2.25.2
# kiwisolver                  1.4.5
# llvmlite                    0.39.1
# markupsafe                  2.1.3
# matplotlib                  3.6.3
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# natsort                     8.4.0
# nbformat                    5.9.2
# nt                          NA
# numba                       0.56.4
# numpy                       1.19.5
# overrides                   NA
# packaging                   23.2
# pandas                      1.4.4
# parso                       0.8.3
# patsy                       0.5.6
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                4.1.0
# prometheus_client           NA
# prompt_toolkit              3.0.41
# psutil                      5.9.0
# pure_eval                   0.2.2
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pyparsing                   3.1.2
# pythoncom                   NA
# pythonjsonlogger            NA
# pytz                        2023.3.post1
# pywin32_bootstrap           NA
# pywin32_system32            NA
# pywintypes                  NA
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.10.1
# seaborn                     0.12.2
# send2trash                  NA
# session_info                1.0.0
# six                         1.16.0
# sklearn                     1.4.2
# sniffio                     1.3.0
# socks                       1.7.1
# stack_data                  0.6.3
# statsmodels                 0.14.1
# threadpoolctl               3.4.0
# torch                       1.7.1+cpu
# tornado                     6.3.3
# tqdm                        4.66.2
# traitlets                   5.14.0
# typing_extensions           NA
# uri_template                NA
# urllib3                     2.1.0
# wcwidth                     0.2.12
# webcolors                   1.13
# websocket                   1.7.0
# win32api                    NA
# win32com                    NA
# win32con                    NA
# win32trace                  NA
# winerror                    NA
# yaml                        6.0.1
# zipp                        NA
# zmq                         25.1.2
# -----
# IPython             8.18.1
# jupyter_client      8.6.0
# jupyter_core        5.5.0
# jupyterlab          4.0.9
# notebook            7.0.6
# -----
# Python 3.9.18 (main, Sep 11 2023, 14:09:26) [MSC v.1916 64 bit (AMD64)]
# Windows-10-10.0.19044-SP0
# -----
# Session information updated at 2024-04-29 10:31
# datetime.timedelta(seconds=4, microseconds=744105)
