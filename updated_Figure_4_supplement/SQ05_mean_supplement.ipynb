# %%
import pandas as pd
import os
import scanpy as sc

# %%
base_path = 'C:\\Users\\vfriedrich\\projects\\gating\\reproducibility'

# %%
cg_mean_performance = os.path.join(os.path.join(os.path.join(base_path,'updated_Figure_4'),'tables'),'Q04_cg_mean_performance.csv')

lin_svm_mean_performance = os.path.join(os.path.join(os.path.join(base_path,'updated_Figure_4_supplement'),'tables'),'Q04_lin_svm_mean_performance.csv')

rbf_svm_mean_performance = os.path.join(os.path.join(os.path.join(base_path,'updated_Figure_4_supplement'),'tables'),'Q04_rbf_svm_mean_performance.csv')

hypergate_mean_performance = os.path.join(os.path.join(os.path.join(base_path,'updated_Figure_4'),'tables'),'Q04_hypergate_mean_performance.csv')

# %%
pd.read_csv(cg_mean_performance,index_col=0)
# Out:
#            tool           panel    level  mean f1  mean precision  mean recall
# 0  ConvexGating  monocyte panel  level 1    0.887           0.989        0.832
# 0  ConvexGating  monocyte panel  level 2    0.745           0.980        0.665
# 0  ConvexGating      PBMC panel  level 1    0.858           0.993        0.782
# 0  ConvexGating      PBMC panel  level 2    0.786           0.940        0.708
# 0  ConvexGating     cyTOF panel  level 2    0.889           0.994        0.814
# 0  ConvexGating     cyTOF panel  level 3    0.725           0.904        0.648
# 0  ConvexGating     cyTOF panel  level 4    0.723           0.894        0.640
# 0  ConvexGating     cyTOF panel  level 5    0.635           0.833        0.548

# %%
pd.read_csv(hypergate_mean_performance,index_col=0)
# Out:
#         tool           panel    level  mean f1  mean precision  mean recall
# 0  Hypergate  monocyte panel  level 1    0.906           0.851        0.995
# 0  Hypergate  monocyte panel  level 2    0.679           0.566        0.997
# 0  Hypergate      PBMC panel  level 1    0.914           0.872        0.982
# 0  Hypergate      PBMC panel  level 2    0.743           0.676        0.979
# 0  Hypergate     cyTOF panel  level 2    0.922           0.885        0.971
# 0  Hypergate     cyTOF panel  level 3    0.648           0.589        0.951
# 0  Hypergate     cyTOF panel  level 4    0.612           0.527        0.947
# 0  Hypergate     cyTOF panel  level 5    0.490           0.388        0.952

# %%
pd.read_csv(lin_svm_mean_performance,index_col=0)
# Out:
#          tool           panel    level  mean f1  mean precision  mean recall
# 0  linear svm  monocyte panel  level 1    0.916           0.930        0.905
# 0  linear svm  monocyte panel  level 2    0.393           0.429        0.460
# 0  linear svm      PBMC panel  level 1    0.970           0.962        0.987
# 0  linear svm      PBMC panel  level 2    0.859           0.926        0.866
# 0  linear svm     cyTOF panel  level 2    0.991           0.993        0.989
# 0  linear svm     cyTOF panel  level 3    0.892           0.942        0.857
# 0  linear svm     cyTOF panel  level 4    0.881           0.927        0.847
# 0  linear svm     cyTOF panel  level 5    0.816           0.884        0.771

# %%
pd.read_csv(rbf_svm_mean_performance,index_col=0)
# Out:
#       tool           panel    level  mean f1  mean precision  mean recall
# 0  rbf svm  monocyte panel  level 1    0.990           0.992        0.987
# 0  rbf svm  monocyte panel  level 2    0.898           0.910        0.888
# 0  rbf svm      PBMC panel  level 1    0.996           0.998        0.994
# 0  rbf svm      PBMC panel  level 2    0.947           0.979        0.931
# 0  rbf svm     cyTOF panel  level 2    0.997           0.997        0.996
# 0  rbf svm     cyTOF panel  level 3    0.953           0.987        0.930
# 0  rbf svm     cyTOF panel  level 4    0.949           0.981        0.926
# 0  rbf svm     cyTOF panel  level 5    0.880           0.925        0.845

# %%
sc.logging.print_header()
# Out:
# scanpy==1.9.5 anndata==0.10.2 umap==0.5.4 numpy==1.19.5 scipy==1.10.1 pandas==1.4.4 scikit-learn==1.3.2 statsmodels==0.14.0 igraph==0.11.2 pynndescent==0.5.10

# %%
import pkg_resources
for package in pkg_resources.working_set:
     print(f"{package.key}=={package.version}")
# Out:
# babel==2.13.1
# qtpy==2.4.1
# sqlalchemy==2.0.23
# send2trash==1.8.2
# anyio==4.1.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==2.4.1
# async-lru==2.0.4
# attrs==23.1.0
# beautifulsoup4==4.12.2
# bleach==6.1.0
# certifi==2023.11.17
# cffi==1.16.0
# charset-normalizer==3.3.2
# colorama==0.4.6
# comm==0.2.0
# debugpy==1.8.0
# decorator==5.1.1
# defusedxml==0.7.1
# exceptiongroup==1.2.0
# executing==2.0.1
# fastjsonschema==2.19.0
# fqdn==1.5.1
# greenlet==3.0.1
# idna==3.6
# importlib-metadata==7.0.0
# ipykernel==6.27.1
# ipython==8.18.1
# ipython-genutils==0.2.0
# ipython-sql==0.5.0
# ipywidgets==8.1.1
# isoduration==20.11.0
# jedi==0.19.1
# json5==0.9.14
# jsonpointer==2.4
# jsonschema==4.20.0
# jsonschema-specifications==2023.11.2
# jupyter==1.0.0
# jupyter-client==8.6.0
# jupyter-console==6.6.3
# jupyter-core==5.5.0
# jupyter-events==0.9.0
# jupyter-lsp==2.2.1
# jupyter-server==2.11.2
# jupyter-server-terminals==0.4.4
# jupyterlab==4.0.9
# ...
