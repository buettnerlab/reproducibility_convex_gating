# %%
import sys
import os
path_helper = ["c:\\","Users","vfriedrich","projects","gating","reproducibility_cleaned","helper"]
sys.path.append(os.path.join(*path_helper))
import helper_reproducibility as hr
import convexgating as cg
import scanpy as sc
import anndata as ann
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib import colors
import seaborn as sb
import os
import re
import json
from pywget import wget
print(sys.executable)
# Out:
# C:\Users\vfriedrich\Anaconda3\envs\gating_env_local_parameter_option\python.exe

# %%
#convexgating==0.1.1 #branch add_parameter_option

# %%
pre = 'CITEseq_04_run_gating'
start_time = hr.get_time()

# %%
path_input_data = hr.return_input_data_path() 
path_output_data = hr.return_output_data_path()
path_output_script = os.path.join(path_output_data,pre)
hr.make_path(os.path.join(path_output_script))

# %%
path_CD16_CD4 = os.path.join(path_output_data,'pdata_CD16_CD4_sub_denoised.h5ad')
path_CD16_CD8 = os.path.join(path_output_data,'pdata_CD16_CD8_sub_denoised.h5ad')

# %% [markdown]
# ## Full panel denoised

# %% [markdown]
# ### CD4

# %%
#CD4 denoised
adata = sc.read_h5ad(path_CD16_CD4)
sc.pp.log1p(adata)
adata = adata.copy()
cluster_string = 'CD16+ T cells'
target_cluster = 'CD16+ CD4+ T cell'
save = os.path.join(path_output_script,target_cluster)
cg.tools.CONVEX_GATING(adata=adata,
              cluster_numbers = [target_cluster],
              cluster_string = cluster_string,
              save_path=save,
              add_noise=True,
              update_anndata=False,
              focus="f1")

# %% [markdown]
# ### CD8

# %%
adata = sc.read_h5ad(path_CD16_CD8)
sc.pp.log1p(adata)
adata = adata.copy()
cluster_string = 'CD16+ T cells'
target_cluster = 'CD16+ CD8+ T cell'
save = os.path.join(path_output_script,target_cluster)
cg.tools.CONVEX_GATING(adata=adata,
              cluster_numbers = [target_cluster],
              cluster_string = cluster_string,
              save_path=save,
              add_noise=True,
              update_anndata=False,
              focus="f1")

# %% [markdown]
# ## FACS panel denoised

# %%
path_FACS_intersect = 'C:\\Users\\vfriedrich\\projects\\gating\\reproducibility_cleaned\\main_Figure_bridge_gap\\Summary\\output_data\\summary_01\\summary_01_intersect_AB_citeseq_FACS.json'
with open(path_FACS_intersect, 'r') as f:
    FACS_panel = json.load(f)

# %% [markdown]
# ### CD4

# %%
adata = sc.read_h5ad(path_CD16_CD4)
sc.pp.log1p(adata)
adata = adata[:,FACS_panel]
adata = adata.copy()
cluster_string = 'CD16+ T cells'
target_cluster = 'CD16+ CD4+ T cell'
save = os.path.join(path_output_script,target_cluster + '_FACS_panel')
cg.tools.CONVEX_GATING(adata=adata,
              cluster_numbers = [target_cluster],
              cluster_string = cluster_string,
              save_path=save,
              add_noise=True,
              update_anndata=False,
              focus="f1")

# %% [markdown]
# ### CD8

# %%
adata = sc.read_h5ad(path_CD16_CD8)
sc.pp.log1p(adata)
adata = adata[:,FACS_panel]
adata = adata.copy()
cluster_string = 'CD16+ T cells'
target_cluster = 'CD16+ CD8+ T cell'
save = os.path.join(path_output_script,target_cluster + '_FACS_panel')
cg.tools.CONVEX_GATING(adata=adata,
              cluster_numbers = [target_cluster],
              cluster_string = cluster_string,
              save_path=save,
              add_noise=True,
              update_anndata=False,
              focus="f1")

# %% [markdown]
# ## Joint CyTOF panel denoised

# %%
path_joint_panel = 'C:\\Users\\vfriedrich\\projects\\gating\\reproducibility_cleaned\\main_Figure_bridge_gap\\Summary\\output_data\\summary_01\\summary_01_intersect_AB_citeseq.json'
with open(path_joint_panel, 'r') as f:
    joint_panel = json.load(f)

# %% [markdown]
# ### CD4

# %%
adata = sc.read_h5ad(path_CD16_CD4)
sc.pp.log1p(adata)
adata = adata[:,joint_panel]
adata = adata.copy()
cluster_string = 'CD16+ T cells'
target_cluster = 'CD16+ CD4+ T cell'
save = os.path.join(path_output_script,target_cluster + '_joint_panel')
cg.tools.CONVEX_GATING(adata=adata,
              cluster_numbers = [target_cluster],
              cluster_string = cluster_string,
              save_path=save,
              add_noise=True,
              update_anndata=False,
              focus="f1")

# %% [markdown]
# ### CD8

# %%
adata = sc.read_h5ad(path_CD16_CD8)
sc.pp.log1p(adata)
adata = adata[:,joint_panel]
adata = adata.copy()
cluster_string = 'CD16+ T cells'
target_cluster = 'CD16+ CD8+ T cell'
save = os.path.join(path_output_script,target_cluster + '_joint_panel')
cg.tools.CONVEX_GATING(adata=adata,
              cluster_numbers = [target_cluster],
              cluster_string = cluster_string,
              save_path=save,
              add_noise=True,
              update_anndata=False,
              focus="f1")

# %% [markdown]
# ## Save Session

# %%
hr.save_package_versions(hr.return_base_package_version_path(),pre = pre,do_print = True)
sc.logging.print_versions()
end_time = hr.get_time()
hr.get_time_delta(start_time,end_time,pre=pre,save=True)
# Out:
# babel==2.13.1
# qtpy==2.4.1
# sqlalchemy==2.0.23
# send2trash==1.8.2
# anyio==4.1.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==2.4.1
# async-lru==2.0.4
# attrs==23.1.0
# beautifulsoup4==4.12.2
# bleach==6.1.0
# certifi==2023.11.17
# cffi==1.16.0
# charset-normalizer==3.3.2
# colorama==0.4.6
# comm==0.2.0
# debugpy==1.8.0
# decorator==5.1.1
# defusedxml==0.7.1
# exceptiongroup==1.2.0
# executing==2.0.1
# fastjsonschema==2.19.0
# fqdn==1.5.1
# greenlet==3.0.1
# idna==3.6
# importlib-metadata==7.0.0
# ipykernel==6.27.1
# ipython==8.18.1
# ipython-genutils==0.2.0
# ipython-sql==0.5.0
# ipywidgets==8.1.1
# isoduration==20.11.0
# jedi==0.19.1
# json5==0.9.14
# jsonpointer==2.4
# jsonschema==4.20.0
# jsonschema-specifications==2023.11.2
# jupyter==1.0.0
# jupyter-client==8.6.0
# jupyter-console==6.6.3
# jupyter-core==5.5.0
# jupyter-events==0.9.0
# jupyter-lsp==2.2.1
# jupyter-server==2.11.2
# jupyter-server-terminals==0.4.4
# jupyterlab==4.0.9
# jupyterlab-pygments==0.3.0
# jupyterlab-server==2.25.2
# jupyterlab-widgets==3.0.9
# matplotlib-inline==0.1.6
# mistune==3.0.2
# nbclient==0.9.0
# nbconvert==7.12.0
# nbformat==5.9.2
# nest-asyncio==1.5.8
# notebook==7.0.6
# notebook-shim==0.2.3
# overrides==7.4.0
# pandocfilters==1.5.0
# parso==0.8.3
# platformdirs==4.1.0
# prettytable==3.9.0
# prometheus-client==0.19.0
# prompt-toolkit==3.0.41
# pure-eval==0.2.2
# pycparser==2.21
# pygments==2.17.2
# python-json-logger==2.0.7
# pywin32==306
# pywinpty==2.0.12
# pyzmq==25.1.2
# qtconsole==5.5.1
# referencing==0.31.1
# requests==2.31.0
# rfc3339-validator==0.1.4
# rfc3986-validator==0.1.1
# rpds-py==0.13.2
# sniffio==1.3.0
# soupsieve==2.5
# sqlparse==0.4.4
# stack-data==0.6.3
# terminado==0.18.0
# tinycss2==1.2.1
# tomli==2.0.1
# traitlets==5.14.0
# types-python-dateutil==2.8.19.14
# uri-template==1.3.0
# urllib3==2.1.0
# wcwidth==0.2.12
# webcolors==1.13
# webencodings==0.5.1
# websocket-client==1.7.0
# widgetsnbextension==4.0.9
# brotli==1.0.9
# jinja2==3.1.3
# markupsafe==2.1.3
# pyqt5==5.15.10
# pyqt5-sip==12.13.0
# pysocks==1.7.1
# pyyaml==6.0.1
# anndata==0.10.5.post1
# array-api-compat==1.6
# backcall==0.2.0
# click==8.1.7
# contourpy==1.1.1
# convexgating==0.1.1
# cycler==0.12.1
# fonttools==4.51.0
# get-annotations==0.1.2
# h5py==3.11.0
# igraph==0.11.4
# joblib==1.4.0
# kiwisolver==1.4.5
# llvmlite==0.39.1
# markdown-it-py==3.0.0
# matplotlib==3.6.3
# matplotlib-venn==0.11.10
# mdurl==0.1.2
# natsort==8.4.0
# networkx==3.2.1
# numba==0.56.4
# numpy==1.19.5
# packaging==23.2
# pandas==1.4.4
# patsy==0.5.6
# pickleshare==0.7.5
# pillow==10.3.0
# pip==23.3.1
# ply==3.11
# psutil==5.9.0
# pydot==2.0.0
# pynndescent==0.5.12
# pyparsing==3.1.2
# python-dateutil==2.8.2
# python-igraph==0.11.4
# pytz==2023.3.post1
# pywget==0.31
# rich==13.7.1
# scanpy==1.9.6
# scikit-learn==1.4.2
# scikit-misc==0.1.4
# scipy==1.10.1
# seaborn==0.12.2
# session-info==1.0.0
# setuptools==68.2.2
# sip==6.7.12
# six==1.16.0
# statsmodels==0.14.1
# stdlib-list==0.10.0
# texttable==1.7.0
# threadpoolctl==3.4.0
# tk==0.1.0
# torch==1.7.1
# tornado==6.3.3
# tqdm==4.66.2
# typing-extensions==4.11.0
# umap-learn==0.5.6
# wheel==0.41.2
# win-inet-pton==1.1.0
# zipp==3.17.0
# -----
# anndata     0.10.5.post1
# scanpy      1.9.6
# -----
# PIL                         10.3.0
# anyio                       NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        23.1.0
# attrs                       23.1.0
# babel                       2.13.1
# brotli                      1.0.9
# certifi                     2023.11.17
# cffi                        1.16.0
# charset_normalizer          3.3.2
# colorama                    0.4.6
# comm                        0.2.0
# convexgating                NA
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.8.0
# decorator                   5.1.1
# defusedxml                  0.7.1
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# fontTools                   4.51.0
# fqdn                        NA
# get_annotations             NA
# h5py                        3.11.0
# helper_reproducibility      NA
# idna                        3.6
# ipykernel                   6.27.1
# ipywidgets                  8.1.1
# isoduration                 NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.4.0
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.20.0
# jsonschema_specifications   NA
# jupyter_events              0.9.0
# jupyter_server              2.11.2
# jupyterlab_server           2.25.2
# kiwisolver                  1.4.5
# llvmlite                    0.39.1
# markupsafe                  2.1.3
# matplotlib                  3.6.3
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# natsort                     8.4.0
# nbformat                    5.9.2
# nt                          NA
# numba                       0.56.4
# numpy                       1.19.5
# overrides                   NA
# packaging                   23.2
# pandas                      1.4.4
# parso                       0.8.3
# patsy                       0.5.6
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                4.1.0
# prometheus_client           NA
# prompt_toolkit              3.0.41
# psutil                      5.9.0
# pure_eval                   0.2.2
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pyparsing                   3.1.2
# pythoncom                   NA
# pythonjsonlogger            NA
# pytz                        2023.3.post1
# pywget                      NA
# pywin32_bootstrap           NA
# pywin32_system32            NA
# pywintypes                  NA
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rpds                        NA
# scipy                       1.10.1
# seaborn                     0.12.2
# send2trash                  NA
# session_info                1.0.0
# six                         1.16.0
# sklearn                     1.4.2
# sniffio                     1.3.0
# socks                       1.7.1
# stack_data                  0.6.3
# statsmodels                 0.14.1
# threadpoolctl               3.4.0
# torch                       1.7.1+cpu
# tornado                     6.3.3
# tqdm                        4.66.2
# traitlets                   5.14.0
# typing_extensions           NA
# uri_template                NA
# urllib3                     2.1.0
# wcwidth                     0.2.12
# webcolors                   1.13
# websocket                   1.7.0
# win32api                    NA
# win32com                    NA
# win32con                    NA
# win32trace                  NA
# winerror                    NA
# yaml                        6.0.1
# zipp                        NA
# zmq                         25.1.2
# -----
# IPython             8.18.1
# jupyter_client      8.6.0
# jupyter_core        5.5.0
# jupyterlab          4.0.9
# notebook            7.0.6
# -----
# Python 3.9.18 (main, Sep 11 2023, 14:09:26) [MSC v.1916 64 bit (AMD64)]
# Windows-10-10.0.19044-SP0
# -----
# Session information updated at 2024-05-02 16:44
# datetime.timedelta(seconds=433, microseconds=697974)
